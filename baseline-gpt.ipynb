# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/chatter-sentiment-transition/__results__.html
# /kaggle/input/chatter-sentiment-transition/df.csv
# /kaggle/input/chatter-sentiment-transition/__notebook__.ipynb
# /kaggle/input/chatter-sentiment-transition/__output__.json
# /kaggle/input/chatter-sentiment-transition/custom.css
# /kaggle/input/chatter-sentiment-transition/__results___files/__results___19_1.png

# %%
df = pd.read_csv("../input/chatter-sentiment-transition/df.csv")

# %%
df.sentiment.unique()
# Out:
# array([' Curious to dive deeper', ' Happy', ' Neutral', ' Surprised',
#        ' Disgusted', ' Sad', ' Fearful', ' Angry'], dtype=object)

# %%
df.loc[df["sentiment"]==' Disgusted']
# Out:
#         conversation_id                                            message  \
# 158                   8   It makes sense when you put it that way but i...
# 235                  11   That's interesting! Of the 1.5 million specie...
# 430                  20                        Lots of rap does have that!
# 436                  20   I suppose.  Just like most music what is play...
# 454                  21   I have no idea what that is, as I don't pay a...
# ...                 ...                                                ...
# 187454             8586   It's pretty crazy how much football players m...
# 187752             8600   I wonder who chose that name. The Fairies?Did...
# 187885             8606   Yep I agree with you! And it only has eightee...
# 188074             8615   right and gillette stadium is actually in fox...
# 188308             8625   These days, guests are probably getting fast ...
#
#          sentiment speaker_id
# 158      Disgusted         8B
# ...

# %%
df.loc[df["conversation_id"]==8]
# Out:
#      conversation_id                                            message  \
# 149                8   Can you believe there is stars that can be co...
# 150                8                    Its amazing and ever evolving.
# 151                8   Yeah and there is even places that exist but ...
# 152                8   They are saying space pulls galaxies outside ...
# 153                8   Yes that is what I was saying, albeit I doubt...
# 154                8   I don't see anything supporting or denying th...
# 155                8   Yeah, but only one ? For all the universe ? I...
# 156                8   There is only one sun that warms earth and al...
# 157                8   Because an electron is part of matter, the wa...
# 158                8   It makes sense when you put it that way but i...
# 159                8   Maybe they did mean to say that our universe ...
# 160                8   I don't know but I am at the end of knowledge...
# ...

# %% [markdown]
# prompt used:
#
# Choose the sentiment of this following sentences ' I think so that they can attempt to make them look like a liar or a fool or whatever negative thing they can think of.' from the following categories' Curious to dive deeper', ' Happy', ' Neutral', ' Surprised',' Disgusted', ' Sad', ' Fearful', ' Angry'".
